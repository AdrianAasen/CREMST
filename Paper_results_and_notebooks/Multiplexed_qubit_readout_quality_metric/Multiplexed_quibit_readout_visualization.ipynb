# %%
# Make sure we can import EMQST_lib from parent directory
import sys
from pathlib import Path

# Go two levels up from current working directory
PROJECT_ROOT = Path.cwd().resolve().parents[1]   # <- one up (your earlier case)


if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Using project root:", PROJECT_ROOT)

# Notebook is in project-root/Multiplexed_qubit_readout_results/
# -> project root is the parent of the current working dir
PROJECT_ROOT = Path.cwd().resolve().parent


if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import numpy as np
import matplotlib.pyplot as plt
import os
import pickle  # or use numpy if .npy
from pathlib import Path
plt.rcParams.update({'font.size': 15})
# Out:
# Using project root: C:\Users\adrian\OneDrive\Skrivebord\PhD\Code\REMQST

# %% [markdown]
# # Fig 1

# %%
import numpy as np
from pathlib import Path

# Directory path
fig1_dir = Path("Fig 1")

# Get all CSV files in the directory
csv_files = list(fig1_dir.glob("*.csv"))

# Check we have exactly two CSV files
if len(csv_files) != 2:
    raise ValueError(f"Expected exactly 2 CSV files in {fig1_dir}, found {len(csv_files)}")

# Load and assign
for file in csv_files:
    data = np.loadtxt(file, delimiter=",")
    if "low" in file.name.lower():
        low = data
        print(f"Loaded '{file.name}' into variable 'low'")
    else:
        high = data
        print(f"Loaded '{file.name}' into variable 'high'")
# Out:
# Loaded '4q_low_power.csv' into variable 'low'
# Loaded '4q_high_power.csv' into variable 'high'

# %%
import numpy as np
import matplotlib.pyplot as plt

freq = low[:, 0]
amplitude_part = low[:, 1]
amplitude_part_high_power_readout = high[:, 1]

# Convert to dB (handle zero or negative values safely by adding a tiny epsilon)
epsilon = 1e-12
amp_low_db = 20 * np.log10(np.abs(amplitude_part) + epsilon)
amp_high_db = 20 * np.log10(np.abs(amplitude_part_high_power_readout) + epsilon)

plt.figure(figsize=(10, 6))
plt.plot(freq, amp_low_db, label='Low power')
plt.plot(freq, amp_high_db, label='High power')

plt.xlabel('Frequency')
plt.ylabel('Amplitude (dB)')
plt.title('Real Part Amplitude vs Frequency in dB')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fig 2

# %% [markdown]
# For simplicity, uncorrected infidelities are called saddata, corrected infidelities are called data

# %%
# Define the base path
base_path = os.path.join("fig 2", "the big Fig 2 database")

# Get all subdirectories and sort them
subdirs = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]
subdirs.sort()  # Sort alphabetically

# Initialize the data lists
data = []
saddata = []

# Load the two arrays from each sorted subdirectory's .npy file
for folder in subdirs:
    qst_path = os.path.join(base_path, folder, "QST_results.npy")
    if os.path.exists(qst_path):
        with open(qst_path, "rb") as f:
            try:
                corrected = np.load(f, allow_pickle=True)
                raw = np.load(f, allow_pickle=True)
                data.append(corrected)
                saddata.append(raw)
            except Exception as e:
                print(f"Error reading from {qst_path}: {e}")
    else:
        print(f"Warning: 'QST_results.npy' not found in {folder}")

# %%
# Assuming 'data' and 'saddata' are already defined and populated

plt.figure(figsize=(6, 4.5))
#print(data)
plt.plot(data[4].mean(axis=0),color = 'blue' ,  label="QREM")
#plt.plot(data[3].mean(axis=0), color = 'blue')
plt.plot(data[2].mean(axis=0), color = 'blue')


sorted_data_2 = np.array([np.sort(data[2][:,row_index]) for row_index in range(len(data[2][0]))])
plt.fill_between(np.arange(len(sorted_data_2)), sorted_data_2.T[3], sorted_data_2.T[-3], color="blue", alpha=0.3)

sorted_data_4 = np.array([np.sort(data[4][:,row_index]) for row_index in range(len(data[4][0]))])
plt.fill_between(np.arange(len(sorted_data_4)), sorted_data_4.T[3], sorted_data_4.T[-3], color="blue", alpha=0.3)

plt.plot(saddata[4].mean(axis=0), color='red', label="std. QST")
plt.plot(saddata[2].mean(axis=0), color='red')

sorted_saddata_2 = np.array([np.sort(saddata[2][:,row_index]) for row_index in range(len(saddata[2][0]))])
plt.fill_between(np.arange(len(sorted_saddata_2)), sorted_saddata_2.T[3], sorted_saddata_2.T[-3], color="red", alpha=0.3)

sorted_saddata_4 = np.array([np.sort(saddata[4][:,row_index]) for row_index in range(len(saddata[4][0]))])
plt.fill_between(np.arange(len(sorted_saddata_4)), sorted_saddata_4.T[3], sorted_saddata_4.T[-3], color="red", alpha=0.3)

# Add thicc horizontal reference lines
for y in [0.1, 0.15, 0.2]:
    plt.axhline(y=y, color='green', linestyle='-.', linewidth=1.5, label="Thresholds" if y == 0.2 else "")  # <-- thicker lines
    plt.text(0.01, y + 0.005, f"{y:.2f}", va='bottom', ha='left',
             transform=plt.gca().get_yaxis_transform(), fontsize=13)



# Detect threshold crossings for mean4 and mean2
threshold = 0.1

crossings4 = np.where(np.diff(np.sign(data[4].mean(axis=0) - threshold)) != 0)[0]
crossings2 = np.where(np.diff(np.sign(data[2].mean(axis=0) - threshold)) != 0)[0]


if len(crossings4) > 0:
    idx4 = crossings4[0]
    plt.plot(idx4, data[4].mean(axis=0)[idx4], '*', color='gold', markersize=12, label="QREM crossing")

if len(crossings2) > 0:
    idx2 = crossings2[0]
    plt.plot(idx2, data[2].mean(axis=0)[idx2], '*', color='gold', markersize=12)


plt.legend(bbox_to_anchor=(0.53, 0.41))
plt.xscale("log")
plt.yscale("log")
plt.xlabel("State tomography shots")
plt.ylabel("Infidelity")
plt.xlim(left=1, right=len(data[4].mean(axis=0)))
#plt.title("Mean QST Results Across Settings")
#plt.grid(True, which='both', linestyle=':', linewidth=0.5)
plt.tight_layout()
plt.savefig("fig_2.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# # Fig 3

# %%
ro_powers= np.linspace(0.2, 0.7, 12)

# Path to the target folder
target_dir = Path("fig 3/readout thresholding vs power")

# Create a dictionary to store the variables
data_vars = {}

# Loop over all .npy files in the directory
for npy_file in target_dir.glob("*.npy"):
    var_name = npy_file.stem  # file name without extension
    try:
        array = np.load(npy_file, allow_pickle=False)
        data_vars[var_name] = array
        print(f"Loaded '{var_name}' from {npy_file.name}")
    except Exception as e:
        print(f"Failed to load {npy_file.name}: {e}")
for var_name, array in data_vars.items():
    globals()[var_name] = array
# Out:
# Loaded 'assignment_fidelities_0' from assignment_fidelities_0.npy
# Loaded 'assignment_fidelities_1' from assignment_fidelities_1.npy
# Loaded 'averaged_infidelity_list_vs_ro_power' from averaged_infidelity_list_vs_ro_power.npy
# Loaded 'err010s_ro' from err010s_ro.npy
# Loaded 'err015s_ro' from err015s_ro.npy
# Loaded 'err020s_ro' from err020s_ro.npy
# Loaded 'list010s_ro' from list010s_ro.npy
# Loaded 'list015s_ro' from list015s_ro.npy
# Loaded 'list020s_ro' from list020s_ro.npy
# Loaded 'positions_0_10s' from positions_0_10s.npy
# Loaded 'positions_0_15s' from positions_0_15s.npy
# Loaded 'positions_0_20s' from positions_0_20s.npy
# Loaded 'std_variance_list_vs_ro_power' from std_variance_list_vs_ro_power.npy

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 8), sharex=True)
manual_optim_index = 6  # Index of the manual optimization point
# --- Top plot ---
ax1.axvline(x=ro_powers[manual_optim_index], color='r', linestyle='--', alpha=0.5)
ax1.errorbar(ro_powers, positions_0_10s, yerr=err010s_ro, label="0.10", fmt='o-',capsize=4)
ax1.errorbar(ro_powers, positions_0_15s, yerr=err015s_ro, label="0.15", fmt='o-',capsize=4)
ax1.errorbar(ro_powers, positions_0_20s, yerr=err020s_ro, label="0.20", fmt='o-',capsize=4)

ax1.set_yscale("log")
ax1.set_ylabel("Shots to reach infidelity thres.")
#ax1.set_title("Position vs Readout Power with Vertical Error Bars")
ax1.grid(True)
ax1.legend()

# Computing the standard deviation for assignment fidelities
N = 2000 # The number of shots used to estimate probabilities
var_mean = 0.5**2*(assignment_fidelities_0*(1-assignment_fidelities_0)/N + assignment_fidelities_1*(1-assignment_fidelities_1)/N)
var_product = (assignment_fidelities_0*(1-assignment_fidelities_0) * assignment_fidelities_1*(1-assignment_fidelities_1)/N**2
                + (assignment_fidelities_0**2 *assignment_fidelities_1* (1-assignment_fidelities_1) )/ N
                + (assignment_fidelities_1**2 * assignment_fidelities_0*(1-assignment_fidelities_0) )/ N)

# --- Bottom plot ---
ax2.errorbar(ro_powers, 0.5 * (assignment_fidelities_0 + assignment_fidelities_1),  yerr=np.sqrt(var_mean),
         label="mean of fidelities",fmt='o-', color= "b", capsize=4)
#ax2.errorbar(rho_powers, )
ax2.errorbar(ro_powers, assignment_fidelities_0 * assignment_fidelities_1, yerr=np.sqrt(var_product),
         label="product of fidelities",fmt='o-', color= "g", capsize=4)
ax2.axvline(x=ro_powers[manual_optim_index], color='r', linestyle='--', alpha=0.5)
ax2.set_xlabel("Readout amplitude (a.u.)")
ax2.set_ylabel("Two-qubit assignment fidelities")
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()

fig.savefig("fig_3.pdf", bbox_inches='tight')

# %% [markdown]
# # Fig 4

# %%
# Path to the directory with the .npy files
data_dir = "fig 4/inf v twpa v2"

# Read all .npy files and assign to variables based on filename
for filename in os.listdir(data_dir):
    if filename.endswith(".npy"):
        var_name = filename[:-4]  # Remove .npy extension
        file_path = os.path.join(data_dir, filename)
        globals()[var_name] = np.load(file_path)

# Create the TWPA power array
twpa_powers = np.linspace(3, 6.7, 11)

manual_optim_index = 8

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 8), sharex=True)

# --- Top plot ---
ax1.axvline(x=twpa_powers[manual_optim_index], color='r', linestyle='--', alpha=0.5)
ax1.errorbar(twpa_powers, list010s_ro, yerr=err010s_ro, fmt='o-', capsize=4, label='0.10')
ax1.errorbar(twpa_powers, list015s_ro, yerr=err015s_ro, fmt='o-', capsize=4, label='0.15')
ax1.errorbar(twpa_powers, list020s_ro, yerr=err020s_ro, fmt='o-', capsize=4, label='0.20')

ax1.set_yscale("log")
ax1.set_ylabel("Shots to reach infidelity thres.")
#ax1.set_title("Position vs Readout Power with Vertical Error Bars")
ax1.grid(True)
ax1.legend()



# Load assignment fidelity arrays
f0 = assignment_fidelities_0
f1 = assignment_fidelities_1

# Compute mean and product
mean_fidelity = (f0 + f1) / 2
product_fidelity = f0 * f1



# Computing the standard deviation for assignment fidelities
N = 2000 # The number of shots used to estimate probabilities
var_mean = 0.5**2*(assignment_fidelities_0*(1-assignment_fidelities_0)/N + assignment_fidelities_1*(1-assignment_fidelities_1)/N)
var_product = (assignment_fidelities_0*(1-assignment_fidelities_0) * assignment_fidelities_1*(1-assignment_fidelities_1)/N**2
                + (assignment_fidelities_0**2 *assignment_fidelities_1* (1-assignment_fidelities_1) )/ N
                + (assignment_fidelities_1**2 * assignment_fidelities_0*(1-assignment_fidelities_0) )/ N)

# --- Bottom plot ---
ax2.errorbar(twpa_powers, 0.5 * (assignment_fidelities_0 + assignment_fidelities_1),  yerr=np.sqrt(var_mean),
         label="mean of fidelities",fmt='o-', color= "b", capsize=4)
#ax2.errorbar(rho_powers, )
ax2.errorbar(twpa_powers, assignment_fidelities_0 * assignment_fidelities_1, yerr=np.sqrt(var_product),
         label="product of fidelities",fmt='o-', color= "g", capsize=4)
ax2.axvline(x=twpa_powers[manual_optim_index], color='r', linestyle='--', alpha=0.5)
ax2.set_xlabel("TWAP pump power (dBm)")
ax2.set_ylabel("Two-qubit assignment fidelities")
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()


fig.savefig("fig_4.pdf", bbox_inches='tight')

# %% [markdown]
# # Fig 5

# %%
import matplotlib.patches as patches
# Define path


fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 8), sharex=True)

ax_list = [ax1, ax2]
limit_array = [0.2,0.3]
span_array = [0.4,0.6]
labels = ['1 qubit', '2 qubits']
for j, ax in enumerate(ax_list):
    dir = f"fig 5/1 and 2 qubit shot budgeting/{j+1}"
    scatters_dir = os.path.join(dir, "scatters")

    # Load arrays from directory 1
    dt_ratios_1 = np.load(f"{dir}/dt_ratios.npy")
    last_corr_inf_1 = np.load(f"{dir}/last_corr_inf.npy")
    last_uncorr_inf_1 = np.load(f"{dir}/last_uncorr_inf.npy")

    # Get and sort subfolders inside 'scatters'
    subfolders = sorted([
        f for f in os.listdir(scatters_dir)
        if os.path.isdir(os.path.join(scatters_dir, f))
    ])

    # Load QST_results.npy into infidelities list
    infidelities = []
    for subfolder in subfolders:
        file_path = os.path.join(scatters_dir, subfolder, "QST_results.npy")
        if os.path.isfile(file_path):
            try:
                data = np.load(file_path, allow_pickle=True)
                infidelities.append(np.array(data))
            except Exception as e:
                print(f"Failed to load {file_path}: {e}")
        else:
            print(f"File not found: {file_path}")

    solid_box = patches.Rectangle((limit_array[j], -.02), span_array[j], 0.5, facecolor='lightgreen', alpha=0.5)
    ax.add_patch(solid_box)

# Plot the main lines#

#ax1.plot(dt_ratios_1, last_uncorr_inf_1, label='Uncorrelated Info (1)', marker='^')

# Add scatter points from infidelities
    for i, dt in enumerate(dt_ratios_1):
        if i < len(infidelities):
            try:
                y_vals = infidelities[i].T[-1]  # last row after transpose
                x_vals = np.full_like(y_vals, dt)
                ax.scatter(x_vals, y_vals, alpha=0.4, label=f'individual QREM' if i == 0 else "", color='teal')
            except Exception as e:
                print(f"Failed to process infidelities[{i}]: {e}")

    ax.plot(dt_ratios_1, last_corr_inf_1, label='mean QREM', linestyle='--', marker='^', color='blue', markersize=10)
    ax.axhline(y=last_uncorr_inf_1[0], color='red', linestyle='--', label='std. QST full budget')
    textstr = f"{labels[j]}"
    props = dict(boxstyle='round', facecolor='lightgreen', alpha=0.5)

    ax.text(0.62, 0.97, textstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    ax.set_ylim(-0.01, 0.35)
    ax.grid(True)
    ax.set_ylabel('Infidelity')
    

ax2.set_xlabel('Ratio of shot budget used for detector tomography')

ax1.legend(loc=2)
fig.tight_layout()



fig.savefig("fig_5.pdf", bbox_inches='tight')

# %% [markdown]
# # Fig 6

# %% [markdown]
# ## Bootstrapping

# %%
from EMQST_lib.qst import QST  
from EMQST_lib import support_functions as sf

import glob
import os

def find_npy_files(root_dir="."):
    """
    Recursively finds all .npy files under root_dir.

    Parameters
    ----------
    root_dir : str
        Root directory to search from (default: current directory).

    Returns
    -------
    list of str
        List of full file paths ending with .npy
    """
    pattern = os.path.join(root_dir, "**", "QST_settings.npy")
    return glob.glob(pattern, recursive=True)
# Base directory
total_mitigated_inf_array = []
total_unmitigated_inf_array = []
shot_numbers = []
for j in range(6):
    base_dir = Path(f"fig 6/3q for 6 shot numbers/{j+1}")
    result_file = find_npy_files(base_dir)
    print(result_file)
    result = np.load(result_file[0], allow_pickle=True).item()
    print(result.keys())
    noisy_povm = result['noise_corrected_POVM_list']
    n_shots_each = result['n_QST_shots_each']
    print(n_shots_each)
    outcomes = result['outcome_index'][0]
    true_states = result['list_of_true_states'][0]


    n_bootstrapped_samples = 1000

    segment_size = n_shots_each
    n_segments = len(outcomes) // segment_size
    sample_size = int(n_shots_each *0.75)
    print(len(outcomes))
    mitigated_inf_array = []
    unmitigated_inf_array = []
    for i in range(n_bootstrapped_samples):
        # Reshape into segments
        segments = outcomes.reshape(n_segments, segment_size)
        #print(segments)
        # Randomly choose 30 entries from each segment
        rng = np.random.default_rng()  # reproducible if you set seed e.g. default_rng(42)
        sampled_segments = np.array([rng.choice(seg, size=sample_size, replace=False) for seg in segments])

        # sampled_segments has shape (261, 30)
        bootstrapped_samples = sampled_segments.reshape(-1)
        if i ==0:
            shot_numbers.append(len(bootstrapped_samples))
        #print(bootstrapped_samples)
        #print(len(bootstrapped_samples))
        qst = QST.quick_setup(n_qubits=3)
        qst.n_averages = 1
        qst.n_shots = len(bootstrapped_samples)
        qst.outcome_index = np.array([bootstrapped_samples])
        qst.perform_MLE(override_POVM_list=noisy_povm)
        rho_estm_mitigated = qst.get_rho_estm()[0]
        mitigated_inf = sf.qubit_infidelity(rho_estm_mitigated, true_states)
        mitigated_inf_array.append(mitigated_inf)
        qst.perform_MLE()
        rho_estm_unmitigated = qst.get_rho_estm()[0]
        unmitigated_inf = sf.qubit_infidelity(rho_estm_unmitigated, true_states)
        unmitigated_inf_array.append(unmitigated_inf)

        #qst.noise_corrected_POVM_list = noisy_povm
        #print(rho_estm)
    total_mitigated_inf_array.append(mitigated_inf_array)
    total_unmitigated_inf_array.append(unmitigated_inf_array)

np.save("fig 6/3q for 6 shot numbers/total_mitigated_inf_array.npy", total_mitigated_inf_array)
np.save("fig 6/3q for 6 shot numbers/total_unmitigated_inf_array.npy", total_unmitigated_inf_array)
np.save("fig 6/3q for 6 shot numbers/shot_numbers.npy", shot_numbers)
# Out:
# ['fig 6\\3q for 6 shot numbers\\1\\2024-08-19_13-43-05_912e0da4-a832-4cdf-ae8b-04eb0328ef32\\QST_settings.npy']
# dict_keys(['n_QST_shots_each', 'list_of_true_states', 'n_qubits', 'MH_steps', 'bank_size', 'n_cores', 'bool_exp_measurements', 'POVM_list', 'noise_corrected_POVM_list', 'n_averages', 'noise_mode', 'outcome_index', 'uncertainty'])
# 3000
# 81000
# ['fig 6\\3q for 6 shot numbers\\2\\2024-08-19_16-40-18_c8d566f4-d928-40de-8100-352cc20eab58\\QST_settings.npy']
# dict_keys(['n_QST_shots_each', 'list_of_true_states', 'n_qubits', 'MH_steps', 'bank_size', 'n_cores', 'bool_exp_measurements', 'POVM_list', 'noise_corrected_POVM_list', 'n_averages', 'noise_mode', 'outcome_index', 'uncertainty'])
# 400
# 10800
# ['fig 6\\3q for 6 shot numbers\\3\\2024-08-19_18-08-15_cdaaf37a-dfb1-4356-8f9a-1b74f756e6a9\\QST_settings.npy']
# dict_keys(['n_QST_shots_each', 'list_of_true_states', 'n_qubits', 'MH_steps', 'bank_size', 'n_cores', 'bool_exp_measurements', 'POVM_list', 'noise_corrected_POVM_list', 'n_averages', 'noise_mode', 'outcome_index', 'uncertainty'])
# 100
# 2700
# ['fig 6\\3q for 6 shot numbers\\4\\2024-08-19_19-09-14_54452c55-4057-42b4-91b2-179ea8415d7e\\QST_settings.npy']
# dict_keys(['n_QST_shots_each', 'list_of_true_states', 'n_qubits', 'MH_steps', 'bank_size', 'n_cores', 'bool_exp_measurements', 'POVM_list', 'noise_corrected_POVM_list', 'n_averages', 'noise_mode', 'outcome_index', 'uncertainty'])
# 6000
# 162000
# ['fig 6\\3q for 6 shot numbers\\5\\2024-08-19_22-08-07_ba03277f-174b-4351-80a9-b8dada259375\\QST_settings.npy']
# dict_keys(['n_QST_shots_each', 'list_of_true_states', 'n_qubits', 'MH_steps', 'bank_size', 'n_cores', 'bool_exp_measurements', 'POVM_list', 'noise_corrected_POVM_list', 'n_averages', 'noise_mode', 'outcome_index', 'uncertainty'])
# 1000
# 27000
# ['fig 6\\3q for 6 shot numbers\\6\\2024-08-19_23-20-00_91bd2eca-755b-47a8-8738-a2cba6d5a8d7\\QST_settings.npy']
# dict_keys(['n_QST_shots_each', 'list_of_true_states', 'n_qubits', 'MH_steps', 'bank_size', 'n_cores', 'bool_exp_measurements', 'POVM_list', 'noise_corrected_POVM_list', 'n_averages', 'noise_mode', 'outcome_index', 'uncertainty'])
# 12000
# 324000

# %% [markdown]
# ## Plotting

# %%
total_mitigated_inf_array = np.load("fig 6/3q for 6 shot numbers/total_mitigated_inf_array.npy")
total_unmitigated_inf_array = np.load("fig 6/3q for 6 shot numbers/total_unmitigated_inf_array.npy")
shot_numbers = np.load("fig 6/3q for 6 shot numbers/shot_numbers.npy")

sorting_array = np.argsort(shot_numbers)
mitigated_array = np.array(total_mitigated_inf_array)[sorting_array]
unmitigated_array = np.array(total_unmitigated_inf_array)[sorting_array]
shot_numbers = np.array(shot_numbers)[sorting_array]

print(len(np.mean(plot_array, axis=1)))
#plt.errorbar(shot_numbers,np.mean(plot_array, axis=1), yerr=np.std(plot_array, axis=1), label="mean of fidelities",fmt='o-', color= "b", capsize=4)


plt.figure(figsize=(6, 4))
plt.errorbar(shot_numbers, np.mean(mitigated_array, axis=1), yerr=np.std(mitigated_array, axis=1), label="QREM", color='blue', fmt='o-', capsize=4)
plt.errorbar(shot_numbers, np.mean(unmitigated_array, axis=1), yerr=np.std(unmitigated_array, axis=1), label="std. QST", color='red', fmt='o-', capsize=4)
plt.yscale("log")
plt.xscale("log")
plt.xlabel("Total shots used for QST")
plt.ylabel("Infidelity")
plt.legend()
plt.savefig("fig_6.pdf", bbox_inches='tight')
# Out:
# 6

# %% [markdown]
# # Fig 7

# %% [markdown]
# ## Generating uncorrelated POVM data

# %%
from EMQST_lib.povm import POVM
from EMQST_lib import dt
from EMQST_lib import support_functions as sf
# Simulating uncorrelated POVM sample fluctuations
n_qubits = 2
n_averages = 100
calib_states = sf.get_calibration_states(n_qubits, "SIC")[0]
num_calib_states = len(calib_states)
shot_range = np.array([50, 100, 400, 800, 1200, 2500, 4000, 8000, 12000, 20000, 30000, 50000, 70000])//num_calib_states


print(shot_range)
true_povm = POVM.generate_computational_POVM(n_qubits)

total_quantum_array = []
total_classical_array = []
for average in range(n_averages):
    quantum_corr_array = []
    classical_corr_array = []
    for n_shots in shot_range:
        return_povm = dt.device_tomography(n_qubits,n_shots,true_povm, calib_states)

        classical_corr_coeff = np.array([povm.get_classical_correlation_coefficient() for povm in return_povm])
        classical_corr_array.append(classical_corr_coeff.mean())

        quantum_corr_coeff = np.array([povm.get_quantum_correlation_coefficient() for povm in return_povm])
        quantum_corr_array.append(quantum_corr_coeff.mean())
    total_quantum_array.append(quantum_corr_array)
    total_classical_array.append(classical_corr_array)


np.save('fig 7/uncorrelated_quantum_array.npy',np.array(total_quantum_array))
np.save('fig 7/uncorrelated_classical_array.npy',np.array(total_classical_array))
# Out:
# [   3    6   25   50   75  156  250  500  750 1250 1875 3125 4375]
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 2.33294855656041e-10
# Runtime of parallel POVM reconstruction 0.15144610404968262
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 2.5269834835750515e-11
# Runtime of parallel POVM reconstruction 0.05488872528076172
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 1.753763106959738e-11
# Runtime of parallel POVM reconstruction 0.07155632972717285
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1350, final distance 3.7581874418046723e-10
# Runtime of parallel POVM reconstruction 0.4951791763305664
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 2.4247267388366467e-11
# Runtime of parallel POVM reconstruction 0.09812641143798828
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 1.9357145053522373e-10
# Runtime of parallel POVM reconstruction 0.10050725936889648
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1100, final distance 4.866435865391594e-10
# Runtime of parallel POVM reconstruction 0.39226341247558594
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 600, final distance 3.807205106731715e-10
# Runtime of parallel POVM reconstruction 0.21453094482421875
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 5.6505567516684785e-09
# Runtime of parallel POVM reconstruction 0.6686251163482666
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 450, final distance 2.1358524671111212e-10
# Runtime of parallel POVM reconstruction 0.16318106651306152
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010161399841308594.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1450, final distance 4.512071688500541e-10
# Runtime of parallel POVM reconstruction 0.4915504455566406
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010223388671875.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1050, final distance 2.9319056904508756e-10
# Runtime of parallel POVM reconstruction 0.35640740394592285
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010046958923339844.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.178993750712177e-08
# Runtime of parallel POVM reconstruction 0.6836605072021484
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 4.415398602297671e-12
# Runtime of parallel POVM reconstruction 0.04942035675048828
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 4.53109771925142e-15
# Runtime of parallel POVM reconstruction 0.04896283149719238
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 2.105566589138963e-10
# Runtime of parallel POVM reconstruction 0.1251974105834961
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 700, final distance 2.035761489938004e-10
# Runtime of parallel POVM reconstruction 0.25229668617248535
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 2.1119939130898047e-11
# Runtime of parallel POVM reconstruction 0.06531786918640137
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 1.3940699983283622e-10
# Runtime of parallel POVM reconstruction 0.09777069091796875
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.00017333030700683594.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 650, final distance 2.8542370203443745e-10
# Runtime of parallel POVM reconstruction 0.22687029838562012
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 3.108813692587198e-10
# Runtime of parallel POVM reconstruction 0.12873101234436035
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.001001119613647461.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.3098565149194386e-09
# Runtime of parallel POVM reconstruction 0.6606042385101318
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1200, final distance 3.340115475869432e-10
# Runtime of parallel POVM reconstruction 0.4163854122161865
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 3.785507046716319e-10
# Runtime of parallel POVM reconstruction 0.6807739734649658
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010018348693847656.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.5788085769297133e-09
# Runtime of parallel POVM reconstruction 0.7322959899902344
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009953975677490234.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.3407556663801454e-08
# Runtime of parallel POVM reconstruction 0.7865173816680908
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 9.028749969886007e-11
# Runtime of parallel POVM reconstruction 0.08088517189025879
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 4.403283293541449e-13
# Runtime of parallel POVM reconstruction 0.07883119583129883
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 1.1471375932492478e-11
# Runtime of parallel POVM reconstruction 0.1300673484802246
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.001081705093383789.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 1.606871996573389e-10
# Runtime of parallel POVM reconstruction 0.19083166122436523
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 3.8739116081654146e-11
# Runtime of parallel POVM reconstruction 0.1352832317352295
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 850, final distance 2.5440037576540675e-10
# Runtime of parallel POVM reconstruction 0.3606734275817871
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 1.073167596454816e-10
# Runtime of parallel POVM reconstruction 0.0824272632598877
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1500, final distance 5.066943947751312e-10
# Runtime of parallel POVM reconstruction 0.6230807304382324
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 4.1027625741207885e-10
# Runtime of parallel POVM reconstruction 0.8394577503204346
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009887218475341797.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 500, final distance 2.523617287364388e-10
# Runtime of parallel POVM reconstruction 0.21179485321044922
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009992122650146484.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.0879029690991082e-09
# Runtime of parallel POVM reconstruction 0.7701175212860107
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009992122650146484.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 700, final distance 2.9000965170999926e-10
# Runtime of parallel POVM reconstruction 0.2834150791168213
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010006427764892578.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.8360105500113697e-08
# Runtime of parallel POVM reconstruction 0.7664229869842529
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 50, final distance 1.0255671312187076e-11
# Runtime of parallel POVM reconstruction 0.03995680809020996
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 3.817882121559535e-11
# Runtime of parallel POVM reconstruction 0.06135964393615723
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 3.053828023791283e-12
# Runtime of parallel POVM reconstruction 0.057213783264160156
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.000988006591796875.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 4.14769607548493e-11
# Runtime of parallel POVM reconstruction 0.15450763702392578
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 1.392036416691944e-10
# Runtime of parallel POVM reconstruction 0.1769886016845703
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 2.5204412862356307e-10
# Runtime of parallel POVM reconstruction 0.15167546272277832
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 5.237258543511203e-11
# Runtime of parallel POVM reconstruction 0.14374876022338867
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009865760803222656.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.354474964993969e-08
# Runtime of parallel POVM reconstruction 0.7683401107788086
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1450, final distance 3.6260885266647946e-10
# Runtime of parallel POVM reconstruction 0.5750181674957275
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.7530921223317684e-09
# Runtime of parallel POVM reconstruction 0.7875595092773438
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009925365447998047.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 650, final distance 2.66577405982904e-10
# Runtime of parallel POVM reconstruction 0.2684051990509033
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010006427764892578.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 550, final distance 3.072235799095324e-10
# Runtime of parallel POVM reconstruction 0.22873878479003906
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.002002239227294922.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.4519382253729294e-08
# Runtime of parallel POVM reconstruction 0.7715706825256348
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 2.095545958979983e-15
# Runtime of parallel POVM reconstruction 0.060302019119262695
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 4.438498180103778e-12
# Runtime of parallel POVM reconstruction 0.12047863006591797
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 500, final distance 1.6105562716806077e-10
# Runtime of parallel POVM reconstruction 0.21895337104797363
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 1.7176537969731953e-13
# Runtime of parallel POVM reconstruction 0.05829811096191406
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1900, final distance 3.8200247132191834e-10
# Runtime of parallel POVM reconstruction 0.7539095878601074
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 2.8581004229977225e-10
# Runtime of parallel POVM reconstruction 0.1496288776397705
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 550, final distance 3.7354839013681307e-10
# Runtime of parallel POVM reconstruction 0.22991394996643066
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 600, final distance 2.517746011676536e-10
# Runtime of parallel POVM reconstruction 0.2539668083190918
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 500, final distance 3.5993041880288956e-10
# Runtime of parallel POVM reconstruction 0.21245098114013672
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 600, final distance 3.7700791793993105e-10
# Runtime of parallel POVM reconstruction 0.2510383129119873
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.00099945068359375.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 650, final distance 4.02227244566955e-10
# Runtime of parallel POVM reconstruction 0.2675962448120117
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009982585906982422.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1350, final distance 4.0570310305687585e-10
# Runtime of parallel POVM reconstruction 0.522425651550293
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0005476474761962891.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1850, final distance 3.2799971766417357e-10
# Runtime of parallel POVM reconstruction 0.7585549354553223
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 3.267424386610429e-10
# Runtime of parallel POVM reconstruction 0.0813136100769043
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 5.0403570206469794e-12
# Runtime of parallel POVM reconstruction 0.07818484306335449
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 7.63361596156642e-13
# Runtime of parallel POVM reconstruction 0.06672883033752441
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 650, final distance 3.859845498777048e-10
# Runtime of parallel POVM reconstruction 0.28243446350097656
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 7.974651494713214e-11
# Runtime of parallel POVM reconstruction 0.15191030502319336
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.13971089457754e-09
# Runtime of parallel POVM reconstruction 0.8002729415893555
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 550, final distance 3.413394983331486e-10
# Runtime of parallel POVM reconstruction 0.22834134101867676
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 3.968023125355824e-09
# Runtime of parallel POVM reconstruction 0.7768616676330566
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.3039440083240095e-09
# Runtime of parallel POVM reconstruction 0.8035893440246582
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0011005401611328125.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 600, final distance 2.5190853396306334e-10
# Runtime of parallel POVM reconstruction 0.24771428108215332
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1950, final distance 4.3718705045048267e-10
# Runtime of parallel POVM reconstruction 0.7561020851135254
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0011954307556152344.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 3.141764123165691e-10
# Runtime of parallel POVM reconstruction 0.17475152015686035
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.000997781753540039.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.6000181804476377e-09
# Runtime of parallel POVM reconstruction 0.793276309967041
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 9.26647925059143e-11
# Runtime of parallel POVM reconstruction 0.0765542984008789
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 1.6883355824504065e-10
# Runtime of parallel POVM reconstruction 0.1986675262451172
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 5.3040905001466854e-14
# Runtime of parallel POVM reconstruction 0.08739900588989258
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 3.0108813706131166e-10
# Runtime of parallel POVM reconstruction 0.16430139541625977
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 2.2028746882174488e-11
# Runtime of parallel POVM reconstruction 0.07797098159790039
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 450, final distance 2.1566254337912483e-10
# Runtime of parallel POVM reconstruction 0.19511651992797852
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 600, final distance 1.8486349256940926e-10
# Runtime of parallel POVM reconstruction 0.24157333374023438
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009992122650146484.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1550, final distance 2.840683591132098e-10
# Runtime of parallel POVM reconstruction 0.5955519676208496
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010023117065429688.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 500, final distance 2.5759454985729846e-10
# Runtime of parallel POVM reconstruction 0.20584750175476074
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009849071502685547.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 500, final distance 2.494941545028162e-10
# Runtime of parallel POVM reconstruction 0.22005009651184082
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 5.222679441696521e-10
# Runtime of parallel POVM reconstruction 0.8010156154632568
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.00099945068359375.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 6.0921196490260066e-09
# Runtime of parallel POVM reconstruction 0.7608065605163574
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.001998424530029297.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 700, final distance 2.960598502466105e-10
# Runtime of parallel POVM reconstruction 0.28061652183532715
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1000, final distance 3.0272516091112145e-10
# Runtime of parallel POVM reconstruction 0.3874502182006836
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 50, final distance 7.179612460106455e-11
# Runtime of parallel POVM reconstruction 0.04146170616149902
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 3.38463763960295e-10
# Runtime of parallel POVM reconstruction 0.15402460098266602
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 700, final distance 2.389672106029028e-10
# Runtime of parallel POVM reconstruction 0.2839689254760742
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 750, final distance 1.7678765396045293e-10
# Runtime of parallel POVM reconstruction 0.30830836296081543
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 2.3568585277855547e-10
# Runtime of parallel POVM reconstruction 0.17251849174499512
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 4.755222604568843e-10
# Runtime of parallel POVM reconstruction 0.17373037338256836
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.001004934310913086.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 500, final distance 9.863472538729212e-11
# Runtime of parallel POVM reconstruction 0.23032879829406738
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010890960693359375.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1650, final distance 4.183503092558549e-10
# Runtime of parallel POVM reconstruction 0.6539525985717773
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010004043579101562.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 450, final distance 3.4014615776789547e-10
# Runtime of parallel POVM reconstruction 0.19940972328186035
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009875297546386719.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 5.3717882086967705e-09
# Runtime of parallel POVM reconstruction 0.7749836444854736
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009946823120117188.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1750, final distance 3.314402086118662e-10
# Runtime of parallel POVM reconstruction 0.6729843616485596
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0019996166229248047.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1250, final distance 3.9402174231706333e-10
# Runtime of parallel POVM reconstruction 0.48465394973754883
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 2.3394469694792974e-10
# Runtime of parallel POVM reconstruction 0.0587615966796875
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009982585906982422.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 4.55954718425744e-14
# Runtime of parallel POVM reconstruction 0.05702090263366699
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 2.0228610453365548e-11
# Runtime of parallel POVM reconstruction 0.1364283561706543
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 7.230252160872475e-11
# Runtime of parallel POVM reconstruction 0.07847833633422852
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.607058891684888e-08
# Runtime of parallel POVM reconstruction 0.7605268955230713
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009961128234863281.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 3.541761883774086e-10
# Runtime of parallel POVM reconstruction 0.11243200302124023
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 600, final distance 1.5157103350205148e-10
# Runtime of parallel POVM reconstruction 0.2419593334197998
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 3.158720507379087e-10
# Runtime of parallel POVM reconstruction 0.17919707298278809
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.001003265380859375.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1350, final distance 3.706723122887112e-10
# Runtime of parallel POVM reconstruction 0.5892593860626221
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010325908660888672.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 950, final distance 3.162330605710473e-10
# Runtime of parallel POVM reconstruction 0.3835444450378418
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 650, final distance 1.7246049033303734e-10
# Runtime of parallel POVM reconstruction 0.267669677734375
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010273456573486328.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1500, final distance 2.616634547925045e-10
# Runtime of parallel POVM reconstruction 0.5947422981262207
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010023117065429688.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.663230053157051e-10
# Runtime of parallel POVM reconstruction 0.7676000595092773
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 2.2898349882893854e-15
# Runtime of parallel POVM reconstruction 0.059015512466430664
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 3.3285769973634416e-11
# Runtime of parallel POVM reconstruction 0.05738115310668945
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 200, final distance 8.400466780522642e-11
# Runtime of parallel POVM reconstruction 0.09715580940246582
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 1.3881745752897245e-10
# Runtime of parallel POVM reconstruction 0.11181354522705078
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 2.378074404063568e-10
# Runtime of parallel POVM reconstruction 0.05757713317871094
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 200, final distance 8.691015962458692e-11
# Runtime of parallel POVM reconstruction 0.10602974891662598
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.1272964889629264e-08
# Runtime of parallel POVM reconstruction 0.7727017402648926
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010023117065429688.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 1.1905443991766518e-10
# Runtime of parallel POVM reconstruction 0.13543200492858887
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 9.709676396241207e-10
# Runtime of parallel POVM reconstruction 0.8285098075866699
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010721683502197266.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 3.4028561218812925e-10
# Runtime of parallel POVM reconstruction 0.7835643291473389
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009884834289550781.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1150, final distance 3.7131579755378397e-10
# Runtime of parallel POVM reconstruction 0.47095155715942383
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009958744049072266.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1500, final distance 4.53216499052278e-10
# Runtime of parallel POVM reconstruction 0.5813117027282715
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.002000570297241211.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.940045651378398e-09
# Runtime of parallel POVM reconstruction 0.7595632076263428
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 5.851855111593807e-11
# Runtime of parallel POVM reconstruction 0.11781907081604004
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 3.7031168409473736e-10
# Runtime of parallel POVM reconstruction 0.05772805213928223
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1650, final distance 3.874825599270437e-10
# Runtime of parallel POVM reconstruction 0.628840446472168
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 1.631399772217268e-10
# Runtime of parallel POVM reconstruction 0.1120920181274414
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 2.91475107938588e-11
# Runtime of parallel POVM reconstruction 0.15707039833068848
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.5769446033708778e-08
# Runtime of parallel POVM reconstruction 0.7753372192382812
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009999275207519531.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 1.181262171412456e-10
# Runtime of parallel POVM reconstruction 0.16255974769592285
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0013661384582519531.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 450, final distance 3.036218360064069e-10
# Runtime of parallel POVM reconstruction 0.19044780731201172
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 8.289760544677449e-11
# Runtime of parallel POVM reconstruction 0.17541122436523438
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010118484497070312.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 9.022774888345353e-11
# Runtime of parallel POVM reconstruction 0.14648771286010742
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 650, final distance 2.819807720655376e-10
# Runtime of parallel POVM reconstruction 0.30808496475219727
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.001996278762817383.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1750, final distance 4.700990048622788e-10
# Runtime of parallel POVM reconstruction 0.7044057846069336
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010213851928710938.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.5963496921854734e-08
# Runtime of parallel POVM reconstruction 0.7979555130004883
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 3.1022406865588437e-13
# Runtime of parallel POVM reconstruction 0.05894303321838379
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 3.82509052210267e-10
# Runtime of parallel POVM reconstruction 0.13487648963928223
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 200, final distance 2.703923890345905e-11
# Runtime of parallel POVM reconstruction 0.09762310981750488
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 4.9080767228204536e-11
# Runtime of parallel POVM reconstruction 0.11905550956726074
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 6.07702776989072e-11
# Runtime of parallel POVM reconstruction 0.13378405570983887
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 550, final distance 2.0749523280128024e-10
# Runtime of parallel POVM reconstruction 0.2395644187927246
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 4.000994535680036e-10
# Runtime of parallel POVM reconstruction 0.1780707836151123
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.650165205168864e-08
# Runtime of parallel POVM reconstruction 0.7667863368988037
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 600, final distance 2.1689128965052262e-10
# Runtime of parallel POVM reconstruction 0.24727201461791992
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 550, final distance 2.665465972939707e-10
# Runtime of parallel POVM reconstruction 0.22071504592895508
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0008559226989746094.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.6290355238368637e-08
# Runtime of parallel POVM reconstruction 0.7826433181762695
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010223388671875.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 700, final distance 2.708645738258575e-10
# Runtime of parallel POVM reconstruction 0.28974485397338867
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.001984119415283203.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.368462045931885e-08
# Runtime of parallel POVM reconstruction 0.7660651206970215
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.002958043005986e-09
# Runtime of parallel POVM reconstruction 0.7966578006744385
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 800, final distance 2.873414770010463e-10
# Runtime of parallel POVM reconstruction 0.3279385566711426
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010001659393310547.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 7.620501452088035e-12
# Runtime of parallel POVM reconstruction 0.05730175971984863
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1000, final distance 2.880484739620215e-10
# Runtime of parallel POVM reconstruction 0.4002807140350342
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 6.508827209472656e-05.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 800, final distance 2.4503848949919416e-10
# Runtime of parallel POVM reconstruction 0.33351922035217285
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 900, final distance 3.722981888054644e-10
# Runtime of parallel POVM reconstruction 0.3714718818664551
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 700, final distance 2.1535837002595315e-10
# Runtime of parallel POVM reconstruction 0.3009157180786133
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.722260786930386e-08
# Runtime of parallel POVM reconstruction 0.7769269943237305
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010061264038085938.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1100, final distance 3.6890034776915215e-10
# Runtime of parallel POVM reconstruction 0.4289114475250244
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 500, final distance 3.2247834264031994e-10
# Runtime of parallel POVM reconstruction 0.2182466983795166
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.789512298761009e-09
# Runtime of parallel POVM reconstruction 0.7769548892974854
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010035037994384766.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1450, final distance 3.9727392903143866e-10
# Runtime of parallel POVM reconstruction 0.5708580017089844
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009996891021728516.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 750, final distance 2.6912886502694633e-10
# Runtime of parallel POVM reconstruction 0.3020758628845215
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 50, final distance 1.0408340855860843e-15
# Runtime of parallel POVM reconstruction 0.03929018974304199
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 4.426486954756115e-12
# Runtime of parallel POVM reconstruction 0.0757608413696289
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0003018379211425781.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 200, final distance 4.0652105293137453e-10
# Runtime of parallel POVM reconstruction 0.10100579261779785
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 2.6783993078982604e-10
# Runtime of parallel POVM reconstruction 0.15712332725524902
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 2.4883609062165135e-10
# Runtime of parallel POVM reconstruction 0.08024311065673828
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009937286376953125.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 200, final distance 1.4904261158577015e-10
# Runtime of parallel POVM reconstruction 0.09306836128234863
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 750, final distance 2.380592181716601e-10
# Runtime of parallel POVM reconstruction 0.3051133155822754
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 2.4433739753693118e-11
# Runtime of parallel POVM reconstruction 0.13292956352233887
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010190010070800781.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1250, final distance 4.036003198315541e-10
# Runtime of parallel POVM reconstruction 0.4983186721801758
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1750, final distance 3.270693646473255e-10
# Runtime of parallel POVM reconstruction 0.682720422744751
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 900, final distance 2.35879121790461e-10
# Runtime of parallel POVM reconstruction 0.3610970973968506
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010929107666015625.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 3.867554276837382e-09
# Runtime of parallel POVM reconstruction 0.7682855129241943
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010292530059814453.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1000, final distance 3.6848532558586555e-10
# Runtime of parallel POVM reconstruction 0.40982508659362793
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 50, final distance 3.28501115198776e-13
# Runtime of parallel POVM reconstruction 0.039287567138671875
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 3.155843988911222e-11
# Runtime of parallel POVM reconstruction 0.1372230052947998
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010883808135986328.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 550, final distance 3.227008694983713e-10
# Runtime of parallel POVM reconstruction 0.23553991317749023
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009791851043701172.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 900, final distance 3.761157461867892e-10
# Runtime of parallel POVM reconstruction 0.3704361915588379
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0001881122589111328.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 7.166824564364127e-10
# Runtime of parallel POVM reconstruction 0.7818024158477783
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009851455688476562.
# Starting POVM reconstruction.
# ...
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 2.2005726407758885e-10
# Runtime of parallel POVM reconstruction 0.11686182022094727
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1250, final distance 3.1160299340804443e-10
# Runtime of parallel POVM reconstruction 0.5024240016937256
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.00099945068359375.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 700, final distance 4.293223207496588e-10
# Runtime of parallel POVM reconstruction 0.3127899169921875
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 600, final distance 2.3667608151090036e-10
# Runtime of parallel POVM reconstruction 0.2608926296234131
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 9.37915058119021e-11
# Runtime of parallel POVM reconstruction 0.15731167793273926
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 650, final distance 2.1753540635494062e-10
# Runtime of parallel POVM reconstruction 0.28141069412231445
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009999275207519531.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 700, final distance 2.750914079863165e-10
# Runtime of parallel POVM reconstruction 0.3193397521972656
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010039806365966797.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 6.599356998371331e-09
# Runtime of parallel POVM reconstruction 0.8371069431304932
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.001008749008178711.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 600, final distance 3.4095283540924726e-10
# Runtime of parallel POVM reconstruction 0.2563953399658203
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009980201721191406.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1550, final distance 4.277998823243312e-10
# Runtime of parallel POVM reconstruction 0.6348831653594971
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009996891021728516.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 3.1481792173160272e-09
# Runtime of parallel POVM reconstruction 0.8303959369659424
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009913444519042969.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 3.7403018182669e-11
# Runtime of parallel POVM reconstruction 0.1363525390625
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 200, final distance 4.17014846265662e-10
# Runtime of parallel POVM reconstruction 0.10303759574890137
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010211467742919922.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 2.969502144178904e-10
# Runtime of parallel POVM reconstruction 0.11858415603637695
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 3.0599023315147633e-10
# Runtime of parallel POVM reconstruction 0.19020509719848633
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 450, final distance 6.970646976300898e-11
# Runtime of parallel POVM reconstruction 0.19405150413513184
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 3.9090160275367936e-10
# Runtime of parallel POVM reconstruction 0.07732963562011719
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 550, final distance 4.814329698787922e-10
# Runtime of parallel POVM reconstruction 0.2625885009765625
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010013580322265625.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 650, final distance 4.0192026790064617e-10
# Runtime of parallel POVM reconstruction 0.29363059997558594
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010952949523925781.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.8205854873952774e-09
# Runtime of parallel POVM reconstruction 0.8156318664550781
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009932518005371094.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 3.10583311846635e-09
# Runtime of parallel POVM reconstruction 0.7892787456512451
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010006427764892578.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 800, final distance 2.718956657044025e-10
# Runtime of parallel POVM reconstruction 0.34493231773376465
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.002000570297241211.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.008875243763141e-08
# Runtime of parallel POVM reconstruction 0.7961061000823975
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 1.1518563880486e-15
# Runtime of parallel POVM reconstruction 0.059557199478149414
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009987354278564453.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 2.0733692540630955e-12
# Runtime of parallel POVM reconstruction 0.060315608978271484
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010018348693847656.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 200, final distance 1.0187214960488689e-10
# Runtime of parallel POVM reconstruction 0.10479140281677246
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 7.441269822550112e-14
# Runtime of parallel POVM reconstruction 0.08342862129211426
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 500, final distance 3.364255957150064e-10
# Runtime of parallel POVM reconstruction 0.2190091609954834
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1550, final distance 3.9363197423814e-10
# Runtime of parallel POVM reconstruction 0.6299562454223633
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010018348693847656.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 350, final distance 3.611617116483501e-10
# Runtime of parallel POVM reconstruction 0.15129494667053223
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 550, final distance 2.950940394819135e-10
# Runtime of parallel POVM reconstruction 0.25512003898620605
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.000997781753540039.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 2.498129696160145e-08
# Runtime of parallel POVM reconstruction 0.8070709705352783
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1150, final distance 4.0137593942946026e-10
# Runtime of parallel POVM reconstruction 0.4619748592376709
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009996891021728516.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 550, final distance 1.0630511054765535e-10
# Runtime of parallel POVM reconstruction 0.2455427646636963
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010263919830322266.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1200, final distance 3.1800649266666703e-10
# Runtime of parallel POVM reconstruction 0.4992671012878418
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009968280792236328.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1800, final distance 3.111710403236323e-10
# Runtime of parallel POVM reconstruction 0.7274641990661621
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 1.6930901125533637e-15
# Runtime of parallel POVM reconstruction 0.05992698669433594
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.001096963882446289.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 200, final distance 3.815461835365852e-12
# Runtime of parallel POVM reconstruction 0.0975792407989502
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010113716125488281.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 950, final distance 2.8586826655851993e-10
# Runtime of parallel POVM reconstruction 0.4252614974975586
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 1.4370726830748026e-11
# Runtime of parallel POVM reconstruction 0.08120346069335938
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010924339294433594.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 500, final distance 1.4605985171334268e-10
# Runtime of parallel POVM reconstruction 0.22233176231384277
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 500, final distance 1.7355334530622102e-10
# Runtime of parallel POVM reconstruction 0.216444730758667
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 7.6025926804002e-09
# Runtime of parallel POVM reconstruction 0.7938992977142334
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.00020456314086914062.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 6.969213997565227e-09
# Runtime of parallel POVM reconstruction 0.8049407005310059
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009913444519042969.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 450, final distance 2.57496232669574e-10
# Runtime of parallel POVM reconstruction 0.19688940048217773
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009655952453613281.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 400, final distance 2.5332858033522143e-10
# Runtime of parallel POVM reconstruction 0.181535005569458
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010001659393310547.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 750, final distance 3.698386527584141e-10
# Runtime of parallel POVM reconstruction 0.3743438720703125
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010399818420410156.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1600, final distance 3.3055692558181526e-10
# Runtime of parallel POVM reconstruction 0.6795864105224609
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.002007722854614258.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1300, final distance 4.184018895236896e-10
# Runtime of parallel POVM reconstruction 0.5287010669708252
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 100, final distance 2.869232629265639e-14
# Runtime of parallel POVM reconstruction 0.06083536148071289
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 150, final distance 2.4998683678667533e-11
# Runtime of parallel POVM reconstruction 0.08133554458618164
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 200, final distance 2.6846770639910034e-10
# Runtime of parallel POVM reconstruction 0.10858654975891113
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 3.3640096264164754e-10
# Runtime of parallel POVM reconstruction 0.11620259284973145
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 250, final distance 1.504600680157786e-10
# Runtime of parallel POVM reconstruction 0.16313767433166504
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010018348693847656.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 2.9626696929074825e-11
# Runtime of parallel POVM reconstruction 0.18864178657531738
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009982585906982422.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 3.176102991719887e-10
# Runtime of parallel POVM reconstruction 0.20710301399230957
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0012679100036621094.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 700, final distance 4.4096230486512233e-10
# Runtime of parallel POVM reconstruction 0.38730359077453613
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 300, final distance 1.6897043486618912e-10
# Runtime of parallel POVM reconstruction 0.1750645637512207
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0020008087158203125.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 900, final distance 4.778330682519982e-10
# Runtime of parallel POVM reconstruction 0.4868161678314209
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0008921623229980469.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 1.6102294962683228e-08
# Runtime of parallel POVM reconstruction 1.0403354167938232
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0009982585906982422.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 2000, final distance 5.048762574677568e-09
# Runtime of parallel POVM reconstruction 0.9623472690582275
# Collecting and sorting QDT data.
# Done collecting and sorting QDT data, total runtime 0.0010137557983398438.
# Starting POVM reconstruction.
# 	Number of MLE iterations: 1200, final distance 3.329114206529482e-10
# Runtime of parallel POVM reconstruction 0.6365129947662354

# %%
for i, corr_array in enumerate(total_quantum_array):
    plt.plot(shot_range, corr_array, label=f"Average {i+1}", alpha=0.2)

plt.errorbar(shot_range, np.mean(total_quantum_array, axis=0), yerr=np.std(total_quantum_array, axis=0), label="Mean ± STD", fmt="o")
plt.errorbar(shot_range, np.mean(total_classical_array, axis=0), yerr=np.std(total_classical_array, axis=0), label="Mean ± STD", fmt="o")
plt.yscale("log")
plt.xscale("log")

# %% [markdown]
# ## Plotting

# %%
# Load uncorrealted simulated data
total_quantum_array = np.load('fig 7/uncorrelated_quantum_array.npy')
total_classical_array = np.load('fig 7/uncorrelated_classical_array.npy')
# Target directory
fig7a_dir = "fig 7/fig 7/A/"

# Dictionary to store loaded arrays
dataA = {}

# Load all .npy files
for file in os.listdir(fig7a_dir):
    if file.endswith('.npy'):
        key = file[:-4]  # Remove '.npy'
        file_path = os.path.join(fig7a_dir, file)
        try:
            arr = np.load(file_path, allow_pickle=True)
            # Ensure we store clean ndarray (not object array)
            if isinstance(arr, np.ndarray) and arr.dtype == object:
                try:
                    arr = np.stack(arr)
                except Exception:
                    arr = np.array(arr)
            dataA[key] = arr
        except Exception as e:
            print(f"Failed to load {file}: {e}")



# Target directory
fig7a_dir = "fig 7/fig 7/C/"

# Dictionary to store loaded arrays
dataC = {}

# Load all .npy files
for file in os.listdir(fig7a_dir):
    if file.endswith('.npy'):
        key = file[:-4]  # Remove '.npy'
        file_path = os.path.join(fig7a_dir, file)
        try:
            arr = np.load(file_path, allow_pickle=True)
            # Ensure we store clean ndarray (not object array)
            if isinstance(arr, np.ndarray) and arr.dtype == object:
                try:
                    arr = np.stack(arr)
                except Exception:
                    arr = np.array(arr)
            dataC[key] = arr
        except Exception as e:
            print(f"Failed to load {file}: {e}")

dt_shot_list_C = [50, 100, 400, 800, 1200, 2500, 4000, 8000, 12000, 20000, 30000, 50000, 70000]

dt_shot_list_A = [50, 100, 400, 800, 1200, 3000, 5000, 10000, 20000, 30000, 50000, 70000]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 8), sharex=True)

ax1.plot(dt_shot_list_A, dataA["quantum_corr_01s"], label = r'$c_{0\rightarrow 1}^Q$',color = 'red', linestyle='-.') 
ax1.plot(dt_shot_list_A, dataA["classical_corr_01s"], label = r'$c_{0\rightarrow 1}^C$', color='red')

ax1.plot(dt_shot_list_A, dataA["quantum_corr_10s"],  label = r'$c_{1\rightarrow 0}^Q$', color='blue', linestyle='-.')
ax1.plot(dt_shot_list_A, dataA["classical_corr_10s"], label = r'$c_{1\rightarrow 0}^C$', color='blue')

textstr = f"System A"
props = dict(boxstyle='round', facecolor='lightgreen', alpha=0.5)

ax1.text(0.42, 0.97, textstr, transform=ax1.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

ax1.set_xscale("log")
ax1.set_yscale("log")
ax1.set_ylabel("Correlation coefficients")

#ax1.set_title("system A")
ax1.legend()

#ax2.errorbar(dt_shot_list_C, np.mean(total_quantum_array, axis=0), yerr=np.std(total_quantum_array, axis=0),
#             label="Uncorrelated quantum Mean ± STD", fmt="o", capsize=4, linestyle='--')
#ax2.errorbar(dt_shot_list_C, np.mean(total_classical_array, axis=0), yerr=np.std(total_classical_array, axis=0),
#             label="Uncorrelated classical Mean ± STD", fmt="o", capsize=4, linestyle='--')

# Plot mean lines
#ax2.plot(dt_shot_list_C, np.mean(total_quantum_array, axis=0), label="Uncorrelated quantum", color="purple", linestyle = '--')
#ax2.plot(dt_shot_list_C, np.mean(total_classical_array, axis=0), label="Uncorrelated classical", color="orange", linestyle='--')

# Fill between for error bars (mean ± std)
quantum_mean = np.mean(total_quantum_array, axis=0)
quantum_std = np.std(total_quantum_array, axis=0)
ax1.fill_between(dt_shot_list_C, quantum_mean - quantum_std, quantum_mean + quantum_std, color="gray", alpha=0.5)

classical_mean = np.mean(total_classical_array, axis=0)
classical_std = np.std(total_classical_array, axis=0)
ax1.fill_between(dt_shot_list_C, classical_mean - classical_std, classical_mean + classical_std, color="gold", alpha=0.4)

ax2.plot(dt_shot_list_C, dataC["quantum_corr_01s"],label = r'$c_{2\rightarrow 3}^Q$', color='red', linestyle='-.')
ax2.plot(dt_shot_list_C, dataC["classical_corr_01s"],label = r'$c_{2\rightarrow 3}^C$', color='red')

ax2.plot(dt_shot_list_C, dataC["quantum_corr_10s"],label = r'$c_{3\rightarrow 2}^Q$', color='blue', linestyle='-.')
ax2.plot(dt_shot_list_C, dataC["classical_corr_10s"],label = r'$c_{3\rightarrow 2}^C$', color='blue')


# Plot mean lines
#ax2.plot(dt_shot_list_C, np.mean(total_quantum_array, axis=0), label="Uncorrelated quantum", color="gray", linestyle = '--')
#ax2.plot(dt_shot_list_C, np.mean(total_classical_array, axis=0), label="Uncorrelated classical", color="gold", linestyle='--')

# Fill between for error bars (mean ± std)
quantum_mean = np.mean(total_quantum_array, axis=0)
quantum_std = np.std(total_quantum_array, axis=0)
ax2.fill_between(dt_shot_list_C, quantum_mean - quantum_std, quantum_mean + quantum_std, color="gray", alpha=0.5)

classical_mean = np.mean(total_classical_array, axis=0)
classical_std = np.std(total_classical_array, axis=0)
ax2.fill_between(dt_shot_list_C, classical_mean - classical_std, classical_mean + classical_std, color="gold", alpha=0.4)

textstr = f"System C"
props = dict(boxstyle='round', facecolor='lightgreen', alpha=0.5)

ax2.text(0.42, 0.97, textstr, transform=ax2.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

ax2.set_yscale("log")
ax2.set_xscale("log")
ax2.set_ylabel("Correlation coefficients")
ax2.set_xlabel("Detector tomography shots")
#ax2.set_title("system C")
ax2.legend()
#plt.show()
ax2.set_xlim(dt_shot_list_C[0]*.95, dt_shot_list_C[-1]*1.05)

fig.tight_layout()




fig.savefig("fig_7.pdf", bbox_inches="tight")

# %% [markdown]
# # Fig 8

# %%
# Define the directory
fig8_dir = "fig 8/fig 8/"

# Dictionary to store the arrays
data = {}

# Load all .npy files into the dictionary
for file in os.listdir(fig8_dir):
    if file.endswith('.npy'):
        key = file[:-4]  # remove '.npy' extension
        file_path = os.path.join(fig8_dir, file)
        try:
            # Ensure result is a NumPy array, not a list or object
            loaded = np.load(file_path, allow_pickle=True)
            data[key] = np.array(loaded)  # force array conversion
        except Exception as e:
            print(f"Failed to load {file}: {e}")
            
dt_shot_list = [50, 100, 400, 800, 2000, 5000, 10000, 25000, 40000]

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 8), sharex=True)


colors_classical = ['orange', "#56B4E9", "#009E73", "#D55E00"]
colors_quantum   = ['orange', "#56B4E9", "#009E73", "#D55E00"]
# Fill between for error bars (mean ± std)

classical_mean = np.mean(total_classical_array, axis=0)
classical_std = np.std(total_classical_array, axis=0)
ax1.fill_between(dt_shot_list_C, classical_mean - classical_std, classical_mean + classical_std, color="gold", alpha=0.4)

ax1.plot(dt_shot_list, np.mean([data["classical_corr_01s_0.1"], data["classical_corr_10s_0.1"]], axis=0), color = colors_classical[0],  label = '0.1', linewidth=2)
ax1.plot(dt_shot_list, np.mean([data["classical_corr_01s_0.25"], data["classical_corr_10s_0.25"]], axis=0), color = colors_classical[1], label = '0.25', linewidth=2)

ax1.plot(dt_shot_list, np.mean([data["classical_corr_01s_0.6"], data["classical_corr_10s_0.6"]], axis=0), color = colors_classical[2], label = '0.6', linewidth=2)
ax1.plot(dt_shot_list, np.mean([data["classical_corr_01s_1"], data["classical_corr_10s_1"]], axis=0), color = colors_classical[3],label = '1', linewidth=2)

ax1.set_xscale("log")
ax1.set_yscale("log")
ax1.legend()
ax1.set_ylabel(r'$c^{C}_{1\leftrightarrow 2}$')
#ax1.set_title("classical corrs")




quantum_mean = np.mean(total_quantum_array, axis=0)
quantum_std = np.std(total_quantum_array, axis=0)
ax2.fill_between(dt_shot_list_C, quantum_mean - quantum_std, quantum_mean + quantum_std, color="gray", alpha=0.5)


ax2.plot(dt_shot_list, np.mean([data["quantum_corr_01s_0.1"], data["quantum_corr_10s_0.1"]], axis=0), color = colors_quantum[0], label = '0.1', linewidth=2)
ax2.plot(dt_shot_list, np.mean([data["quantum_corr_01s_0.25"], data["quantum_corr_10s_0.25"]], axis=0), color = colors_quantum[1], label = '0.25', linewidth=2)
ax2.plot(dt_shot_list, np.mean([data["quantum_corr_01s_0.6"], data["quantum_corr_10s_0.6"]], axis=0), color = colors_quantum[2], label = '0.6', linewidth=2)
ax2.plot(dt_shot_list, np.mean([data["quantum_corr_01s_1"], data["quantum_corr_10s_1"]], axis=0), color = colors_quantum[3], label = '1', linewidth=2)
ax2.set_xscale("log")
ax2.set_yscale("log")
ax2.set_ylabel(r'$c^{Q}_{1\leftrightarrow 2}$')
ax2.set_xlabel("Detector tomography shots")
ax2.set_xlim(dt_shot_list[0], dt_shot_list[-1])
ax2.legend()
#ax2.set_title("quantum corrs")
fig.tight_layout()
fig.savefig("fig_8.pdf", bbox_inches="tight")

# %% [markdown]
# # Fig 9

# %%
ro_powers= np.linspace(0.2, 0.7, 12)

# Path to the target folder
target_dir = Path("fig 3/readout thresholding vs power")

# Create a dictionary to store the variables
data_vars = {}

# Loop over all .npy files in the directory
for npy_file in target_dir.glob("*.npy"):
    var_name = npy_file.stem  # file name without extension
    try:
        array = np.load(npy_file, allow_pickle=False)
        data_vars[var_name] = array
        print(f"Loaded '{var_name}' from {npy_file.name}")
    except Exception as e:
        print(f"Failed to load {npy_file.name}: {e}")
for var_name, array in data_vars.items():
    globals()[var_name] = array
# Out:
# Loaded 'assignment_fidelities_0' from assignment_fidelities_0.npy
# Loaded 'assignment_fidelities_1' from assignment_fidelities_1.npy
# Loaded 'averaged_infidelity_list_vs_ro_power' from averaged_infidelity_list_vs_ro_power.npy
# Loaded 'err010s_ro' from err010s_ro.npy
# Loaded 'err015s_ro' from err015s_ro.npy
# Loaded 'err020s_ro' from err020s_ro.npy
# Loaded 'list010s_ro' from list010s_ro.npy
# Loaded 'list015s_ro' from list015s_ro.npy
# Loaded 'list020s_ro' from list020s_ro.npy
# Loaded 'positions_0_10s' from positions_0_10s.npy
# Loaded 'positions_0_15s' from positions_0_15s.npy
# Loaded 'positions_0_20s' from positions_0_20s.npy
# Loaded 'std_variance_list_vs_ro_power' from std_variance_list_vs_ro_power.npy

# %%
# Navigate to the directory
folder_path = os.path.join("fig 9", "random leakage files")

# Load the .npy files
x_vals = np.load(os.path.join(folder_path, "leaked_ratio_xvals.npy"))
q0_vals = np.load(os.path.join(folder_path, "leaked_ratio_q0.npy"))
q1_vals = np.load(os.path.join(folder_path, "leaked_ratio_q1.npy"))


fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 8), sharex=True)

ax1.text(0.02, 0.95, "(a)", transform=ax1.transAxes,
         fontsize=14, fontweight="bold", va="top", ha="left")
ax2.text(0.02, 0.95, "(b)", transform=ax2.transAxes,
         fontsize=14, fontweight="bold", va="top", ha="left")
ax3.text(0.02, 0.95, "(c)", transform=ax3.transAxes,
         fontsize=14, fontweight="bold", va="top", ha="left")
ax4.text(0.02, 0.95, "(d)", transform=ax4.transAxes,
         fontsize=14, fontweight="bold", va="top", ha="left")

manual_optim_index = 6  # Index of the manual optimization point
# --- Top plot ---
ax1.axvline(x=ro_powers[manual_optim_index], color='r', linestyle='--', alpha=0.5)
ax1.errorbar(ro_powers, positions_0_10s, yerr=err010s_ro, label="0.10", fmt='o-',capsize=4)
ax1.errorbar(ro_powers, positions_0_15s, yerr=err015s_ro, label="0.15", fmt='o-',capsize=4)
ax1.errorbar(ro_powers, positions_0_20s, yerr=err020s_ro, label="0.20", fmt='o-',capsize=4)

ax1.set_yscale("log")
ax1.set_ylabel("Shots to reach infidelity thres.")
#ax1.set_title("Position vs Readout Power with Vertical Error Bars")
ax1.grid(True)
ax1.legend(loc=(0.2, 0.7))




print(assignment_fidelities_0)
N_1 = 1000
# --- Bottom plot ---
ax2.errorbar(ro_powers,  assignment_fidelities_0,  yerr=np.sqrt(assignment_fidelities_0*(1-assignment_fidelities_0)/N_1),
         label="assign. fidelity q0",fmt='o-', color= "b", capsize=4)
#ax2.errorbar(rho_powers, )
ax2.errorbar(ro_powers,  assignment_fidelities_1, yerr=np.sqrt(assignment_fidelities_1*(1-assignment_fidelities_1)/N_1),
         label="assign. fidelity q1",fmt='o-', color= "g", capsize=4)
ax2.axvline(x=ro_powers[manual_optim_index], color='r', linestyle='--', alpha=0.5)
#ax2.set_xlabel("Readout amplitude (a.u.)")
ax2.set_ylabel("Single shot assig. fidelities")
ax2.grid(True)
ax2.legend()



# Computing the standard deviation for assignment fidelities
N = 2000 # The number of shots used to estimate probabilities
var_mean = 0.5**2*(assignment_fidelities_0*(1-assignment_fidelities_0)/N + assignment_fidelities_1*(1-assignment_fidelities_1)/N)
var_product = (assignment_fidelities_0*(1-assignment_fidelities_0) * assignment_fidelities_1*(1-assignment_fidelities_1)/N**2
                + (assignment_fidelities_0**2 *assignment_fidelities_1* (1-assignment_fidelities_1) )/ N
                + (assignment_fidelities_1**2 * assignment_fidelities_0*(1-assignment_fidelities_0) )/ N)

# --- Bottom plot ---
ax3.errorbar(ro_powers, 0.5 * (assignment_fidelities_0 + assignment_fidelities_1),  yerr=np.sqrt(var_mean),
         label="mean of fidelities",fmt='o-', color= "b", capsize=4)
#ax2.errorbar(rho_powers, )
ax3.errorbar(ro_powers, assignment_fidelities_0 * assignment_fidelities_1, yerr=np.sqrt(var_product),
         label="product of fidelities",fmt='o-', color= "g", capsize=4)
ax3.axvline(x=ro_powers[manual_optim_index], color='r', linestyle='--', alpha=0.5)
ax3.set_xlabel("Readout amplitude (a.u.)")
ax3.set_ylabel("Two-qubit assignment fidelities")
ax3.grid(True)
ax3.legend()


# Plotting
ax4.plot(x_vals, q0_vals/1000, label="q0", marker='o', color='b', linestyle='--')
ax4.plot(x_vals, q1_vals/1000, label="q1", marker='o', color='g', linestyle='--')
ax4.axvline(x=ro_powers[manual_optim_index], color='r', linestyle='--', alpha=0.5)
ax4.set_xlabel("Readout amplitude (a.u.)")
ax4.set_ylabel("State leakage probability")

ax4.legend(loc=(0.2, 0.78))
ax4.grid(True)



fig.tight_layout()
fig.savefig("fig_9.pdf", bbox_inches="tight")
# Out:
# [0.9253 0.9415 0.952  0.9543 0.9485 0.9471 0.9408 0.9111 0.8643 0.8129
#  0.7703 0.7298]

# %% [markdown]
# ## Fig 10

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# Define the folder path
folder_path = os.path.join("twpa data", "much twpa data")

# Load the .npy files
powers = np.load(os.path.join(folder_path, "app q0q1 twpa powers.npy"))
fids0 = np.load(os.path.join(folder_path, "app q0q1 twpa fids0.npy"))
fids1 = np.load(os.path.join(folder_path, "app q0q1 twpa fids1.npy"))

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(powers, fids0, label="Fidelity q0", marker='o')
plt.plot(powers, fids1, label="Fidelity q1", marker='s')
plt.xlabel("TWPA Power (units?)")
plt.ylabel("Fidelity")
plt.title("Fidelity vs TWPA Power")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fig 11

# %%
coh_err_xx_mixed_ac = np.load("Fig 11/povm drift v2/coherent_errors_xx_rotated_ac off then on.npy")
coh_err_xx_pure_ac = np.load("Fig 11/povm drift v2/coherent_errors_xx_rotated_ac on.npy")

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Define paths
base_path = "Fig 11/povm drift v2"
folders = ["ac on", "ac mixed"]

# Set up figure
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Environmental and Coherent Error Drift', fontsize=16)

for idx, folder in enumerate(folders):
    path = os.path.join(base_path, folder)
    
    # Load data
    start_times = np.load(os.path.join(path, "start_times_list.npy"))
    temperature = np.load(os.path.join(path, "temperature_list.npy"))
    humidity = np.load(os.path.join(path, "humidity_list.npy"))
    coherent_zz = np.load(os.path.join(path, "coherent_errors_zz.npy"))
    coherent_xx = np.load(os.path.join(path, "coherent_errors_xx_rotated.npy"))

    # Time axis in hours
    time_axis = (start_times - start_times[0]) / 3600  # seconds to hours

    # Subplot: Coherent errors vs time
    ax_err = axes[idx, 0]
    ax_err.plot(time_axis, coherent_zz, label='ZZ error')
    ax_err.plot(time_axis, coherent_xx, label='XX rotated error')
    ax_err.set_title(f'Coherent Errors vs Time ({folder})')
    ax_err.set_xlabel('Time (hours)')
    ax_err.set_ylabel('Coherent Error')
    ax_err.legend()
    ax_err.grid(True)

    # Subplot: Temperature & Humidity vs time
    ax_env = axes[idx, 1]
    ax_env.plot(time_axis, temperature, label='Temperature (°C)')
    ax_env.plot(time_axis, humidity, label='Humidity (%)')
    ax_env.set_title(f'Temp & Humidity vs Time ({folder})')
    ax_env.set_xlabel('Time (hours)')
    ax_env.set_ylabel('Environmental Values')
    ax_env.legend()
    ax_env.grid(True)

# Layout
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # leave space for suptitle
plt.show()

# %% [markdown]
# # Fig 12

# %%
# Base directory
fig12_dir = Path("fig 12")

# File paths
qst_results_path = fig12_dir / "QST_results.npy"
qst_settings_path = fig12_dir / "QST_settings.npy"
dt_settings_path = fig12_dir / "DT_settings.npy"

# Dictionary to hold loaded data
data = {}

# Helper function to load with feedback
def load_npy(path, name):
    if path.exists():
        try:
            arr = np.load(path, allow_pickle=True)
            data[name] = arr
            print(f"Loaded {name} successfully.")
        except Exception as e:
            print(f"Failed to load {name}: {e}")
    else:
        print(f"{name} not found at {path}")

# Load each file
load_npy(qst_results_path, "QST_results")
load_npy(qst_settings_path, "QST_settings")
load_npy(dt_settings_path, "DT_settings")

# If they're dictionaries or objects, you can extract them like:
try:
    qst_results = data["QST_results"].item()
    qst_settings = data["QST_settings"].item()
    dt_settings = data["DT_settings"].item()
except Exception as e:
    print(f"Could not convert to dicts/objects: {e}")
# Out:
# Loaded QST_results successfully.
# Failed to load QST_settings: No module named 'EMQST_lib'
# Failed to load DT_settings: No module named 'EMQST_lib'
# Could not convert to dicts/objects: can only convert an array of size 1 to a Python scalar

# %% [markdown]
# I dont have EMQST installed and cannot install it, but now you should have the data to plot the density matrix that is reconstructed.

# %% [markdown]
# Here is the density matrix we wanted to reconstruct (and then just plot the differences of the reconstructed and theoretical one to get to the plot 13 in the paper)

# %%
dm_theory = np.load("fig 12/true 3q state.npy")[0]
plt.imshow(np.real(dm_theory))
plt.show()
plt.imshow(np.imag(dm_theory))
